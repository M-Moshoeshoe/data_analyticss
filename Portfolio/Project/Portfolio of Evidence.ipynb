# %%
import os
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from collections import Counter


with open('C:/Users/HP/Desktop/Portfolio/un_declaration_hr_text_data.txt', 'r') as file:
    text = file.read().replace('\n', ' ')

    stop_wrds = set(stopwords.words('english'))
wordcloud = WordCloud( stopwords=stop_wrds,height = 600, width = 600,background_color="black").generate(text)

plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('word_cloud.png')
plt.show()


#word tokenize
token = nltk.word_tokenize(text.lower())

#removing the stop words
token = [word for word in token if word.isalpha() and word not in stop_wrds]

repetition_dist = Counter(words)

#retrieving the top 25 repetitive terms
frequent_words = repetition_dist.most_common(25)

plt.figure(figsize=(16, 9))
plt.bar(*zip(*frequent_words))
plt.xlabel('Words')
plt.ylabel('Number of repetetions')
plt.title('The 25 top frequent terms')
plt.xticks(rotation=90)
plt.savefig('barplot.png')
plt.show()
